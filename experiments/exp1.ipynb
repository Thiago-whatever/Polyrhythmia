# %%
#make the import of music21 tools
from music21 import converter, instrument, note, chord, stream

# %%
f=note.Note("F5")

#show the information that the variable f holds
print(f.name)
print(f.octave)
print(f.pitch)
print(f.pitch.frequency)
# Out:
# F
# 5
# F5
# 698.456462866008

# %%
#more information
bflat=note.Note("B-2")

print(bflat.pitch.accidental)

acc = bflat.pitch.accidental
acc.alter
# Out:
# flat
# -1.0

# %%
#play the note
f.show('midi')
# Out:
#         <div id="midiPlayerDiv67"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv67_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv67");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv67_play, 2000);
#         } else {
#             midiPlayerDiv67_play();
#         }
#         </script>

# %%
n1 = note.Note()
n1.pitch.nameWithOctave = 'E-5'
n1.duration.quarterLength = 3.0

n1.show('midi')
# Out:
#         <div id="midiPlayerDiv81"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv81_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv81");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv81_play, 2000);
#         } else {
#             midiPlayerDiv81_play();
#         }
#         </script>

# %%
from music21 import duration

#create the duration of half a note
#Music21 Durations use the common American duration types: “whole”, “half”, “quarter”, “eighth”, “16th”, “32nd”, “64th”
#Note that for durations shorter than an eighth note, we use numbers instead of spelling out the whole name of the Duration type.
halfDuration = duration.Duration('half')

#other way of creating a duration object
#we could have created our half note Duration by saying 2 or 2.0
dottedQuarter = duration.Duration(1.5)


print("QL: ",dottedQuarter.quarterLength)

#The .type attribute tells you what general type of Duration you have:
print("Type: ",halfDuration.type)

#keeps track of the fact that the dottedQuarter variable has a dot
print("Dots (halfDuration): ", halfDuration.dots)
print("Dots (dottedQuarter): ",dottedQuarter.dots)

dottedQuarter.dots = 2
print("New QL: ", dottedQuarter.quarterLength)

dottedQuarter.quarterLength = 0.25
print("New type: ",dottedQuarter.type)
# Out:
# QL:  1.5
# Type:  half
# Dots (halfDuration):  0
# Dots (dottedQuarter):  1
# New QL:  1.75
# New type:  16th

# %%
#Working with multiple objects on lists
note1 = note.Note("C4")
note2 = note.Note("F#4")
note3 = note.Note("B-2")

note1.duration.type = 'half'
note1.duration.quarterLength

print(note1.step)
print(note2.step)

noteList = [note1, note2]
print(noteList)
# Out:
# C
# F
# [<music21.note.Note C>, <music21.note.Note F#>]

# %% [markdown]
# The Stream object and its subclasses (Score, Part, Measure) are the fundamental containers for music21 objects
# such as Note, Chord, Clef, TimeSignature objects.
#
# A container is like a Python list (or an array in some languages).
#
# Objects stored in a Stream are generally spaced in time; each stored object has an offset usually representing
# how many quarter notes it lies from the beginning of the Stream. For instance in a 4/4 measure of two half notes,
# the first note will be at offset 0.0, and the second at offset 2.0.
#
# Streams, further, can store other Streams, permitting a wide variety of nested, ordered, and timed structures.
# These stored streams also have offsets. So if we put two 4/4 Measure objects (subclasses of Stream) into a Part
# (also a type of Stream), then the first measure will be at offset 0.0 and the second measure will be at offset 4.0.
#
# Commonly used subclasses of Streams include the Score, Part, and Measure. It is important to grasp that any time we
# want to collect and contain a group of music21 objects, we put them into a Stream. Streams can also be used for less
# conventional organizational structures. We frequently will build and pass around short-lived, temporary Streams, since
# doing this opens up a wide variety of tools for extracting, processing, and manipulating objects on the Stream. For
# instance, if you are looking at only notes on beat 2 of any measure, you’ll probably want to put them into a Stream as well.

# %%
stream1 = stream.Stream()

stream1.append(note1)
stream1.append(note2)
stream1.append(note3)

stream2 = stream.Stream()
n3 = note.Note('D#5')  # octave values can be included in creation arguments
stream2.repeatAppend(n3, 4) # this will append to the stream 4 times n3 with the same duration
stream2.show('midi')
# Out:
#         <div id="midiPlayerDiv113"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv113_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv113");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv113_play, 2000);
#         } else {
#             midiPlayerDiv113_play();
#         }
#         </script>
