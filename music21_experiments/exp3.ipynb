# %%
from music21 import *
cMinor = chord.Chord(["C4","G4","E-5"])

# %%
cMinor.duration.type = 'half'
cMinor.quarterLength
# Out:
# 2.0

# %%
#instead of pitch, a chord has pitches
cMinor.pitches
# Out:
# (<music21.pitch.Pitch C4>, <music21.pitch.Pitch G4>, <music21.pitch.Pitch E-5>)

# %%
cMinor.isMinorTriad()
# Out:
# True

# %%
cMajor = chord.Chord(["E3","C4","G4"])
cMajor.inversion()
# Out:
# 1

# %%
print(cMajor.root())
print(cMajor.bass())
# Out:
# C4
# E3

# %%
d = note.Note('D4')
fSharp = note.Note('F#4')
a = note.Note('A5')
dMajor = chord.Chord([d, fSharp, a])

dMajor.show('midi')
# Out:
#         <div id="midiPlayerDiv13"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv13_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv13");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv13_play, 2000);
#         } else {
#             midiPlayerDiv13_play();
#         }
#         </script>

# %%
e7 = chord.Chord("E4 G#4 B4 D5")

es = chord.Chord("E- G B-")

fMajor = chord.Chord("F A C")

cMinor = chord.Chord("C E- G")


stream1 = stream.Stream()
stream1.append(cMinor)
stream1.append(fMajor)
stream1.append(es)
stream1.show('midi')
# Out:
#         <div id="midiPlayerDiv106"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv106_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv106");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv106_play, 2000);
#         } else {
#             midiPlayerDiv106_play();
#         }
#         </script>

# %%
rest1 = note.Rest()
rest1.quarterLength = 0.5
noteASharp = note.Note('A#5')
noteASharp.quarterLength = 1.5
fminor = chord.Chord('F B- C E- G')
bb9= chord.Chord('B- A- C D G')
ebmaj9= chord.Chord('E- G B- D F')

stream2 = stream.Stream()
# stream2.append(cMinor)
# stream2.append(rest1)
# stream2.append(noteASharp)
stream2.append(fminor)
stream2.append(bb9)
stream2.append(ebmaj9)
stream2.show('midi')
# Out:
#         <div id="midiPlayerDiv196"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv196_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv196");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv196_play, 2000);
#         } else {
#             midiPlayerDiv196_play();
#         }
#         </script>
